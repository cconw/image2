# %%
def dodge(front,back):
    result=front*255/(255-back) 
    result[result>255]=255
    result[back==255]=255
    return result.astype('uint8')

# %%
import numpy as np
def grayscale(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
img ="kt.jpg"

# %%
import imageio
s = imageio.imread(img)
g=grayscale(s)
i = 255-g
import scipy.ndimage
b = scipy.ndimage.filters.gaussian_filter(i,sigma=20)
r= dodge(b,g)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.imshow(r, cmap="bone")

# %%
plt.imsave('kt.png', r, cmap='bone', vmin=0, vmax=255)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.imshow(r, cmap="ocean")

# %%
plt.imsave('kt2.png', r, cmap = 'ocean', vmin=0, vmax=255)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.imshow(r, cmap="terrain")

# %%
plt.imsave('k3.png', r, cmap = 'terrain', vmin=0, vmax=255)

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.imshow(r, cmap="gray")

# %%
plt.imsave('kt4.png', r, cmap = 'gray', vmin=0, vmax=255)
